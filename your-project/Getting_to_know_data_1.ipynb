# %%
import os
import pandas as pd
import numpy as np
import datetime
from datetime import time

# %%
os.getcwd()
# Out:
# '/home/salva/Desktop/Suprafolder/Projects/Project_4/Project-Week-5-Your-Own-Project/your-project'

# %%
renfe = pd.read_csv("../Data/renfe.csv")

# %%
renfe.head()
# Out:
#    Unnamed: 0          insert_date  origin destination           start_date  \
# 0           0  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 06:20:00
# 1           1  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 07:00:00
# 2           2  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 07:30:00
# 3           3  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 08:00:00
# 4           4  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 08:30:00
#
#               end_date train_type  price train_class   fare
# 0  2019-05-29 09:16:00    AV City  38.55     Turista  Promo
# 1  2019-05-29 09:32:00        AVE  53.40     Turista  Promo
# 2  2019-05-29 09:51:00        AVE  47.30     Turista  Promo
# 3  2019-05-29 10:32:00        AVE  69.40  Preferente  Promo
# 4  2019-05-29 11:14:00      ALVIA    NaN     Turista  Promo

# %%
renfe.columns
# Out:
# Index(['Unnamed: 0', 'insert_date', 'origin', 'destination', 'start_date',
#        'end_date', 'train_type', 'price', 'train_class', 'fare'],
#       dtype='object')

# %%
renfe.tail()
# Out:
#          Unnamed: 0          insert_date  origin destination  \
# 2579766     2579766  2019-04-19 05:31:38  MADRID     SEVILLA
# 2579767     2579767  2019-04-19 05:31:38  MADRID     SEVILLA
# 2579768     2579768  2019-04-19 05:31:38  MADRID     SEVILLA
# 2579769     2579769  2019-04-19 05:31:38  MADRID     SEVILLA
# 2579770     2579770  2019-04-19 05:31:38  MADRID     SEVILLA
#
#                   start_date             end_date train_type  price  \
# 2579766  2019-05-30 19:00:00  2019-05-30 21:38:00        AVE  76.30
# 2579767  2019-05-30 19:30:00  2019-05-30 22:05:00        AVE  76.30
# 2579768  2019-05-30 20:00:00  2019-05-30 22:21:00        AVE  72.30
# 2579769  2019-05-30 20:35:00  2019-05-30 23:15:00        AVE  76.30
# 2579770  2019-05-30 21:25:00  2019-05-31 00:10:00    AV City  49.15
#
#           train_class      fare
# 2579766       Turista  Flexible
# 2579767       Turista  Flexible
# 2579768  Turista Plus     Promo
# 2579769       Turista  Flexible
# ...

# %%
renfe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579771 entries, 0 to 2579770
# Data columns (total 10 columns):
# Unnamed: 0     int64
# insert_date    object
# origin         object
# destination    object
# start_date     object
# end_date       object
# train_type     object
# price          float64
# train_class    object
# fare           object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 196.8+ MB

# %%
renfe.destination.value_counts()
# Out:
# MADRID        1220348
# BARCELONA      480074
# SEVILLA        413155
# VALENCIA       399679
# PONFERRADA      66515
# Name: destination, dtype: int64

# %%
renfe.origin.value_counts()
# Out:
# MADRID        1359423
# BARCELONA      405621
# SEVILLA        398445
# VALENCIA       323086
# PONFERRADA      93196
# Name: origin, dtype: int64

# %%
renfe.train_class.value_counts()
# Out:
# Turista               1950303
# Preferente             256082
# Turista Plus           192908
# Turista con enlace     169549
# Cama Turista             1051
# Cama G. Clase             214
# Name: train_class, dtype: int64

# %%
renfe.train_type.value_counts()
# Out:
# AVE          1789258
# ALVIA         182267
# REGIONAL      145898
# INTERCITY      99840
# AV City        72791
# MD-LD          51585
# LD             41209
# AVE-TGV        34755
# AVE-MD         34182
# R. EXPRES      31918
# AVE-LD         31472
# LD-MD          27305
# TRENHOTEL      19348
# MD-AVE          7592
# MD              5543
# LD-AVE          4808
# Name: train_type, dtype: int64

# %%
renfe.astype({"insert_date":"datetime64[ns]"})
# Out:
#          Unnamed: 0         insert_date  origin destination  \
# 0                 0 2019-04-19 05:31:43  MADRID     SEVILLA
# 1                 1 2019-04-19 05:31:43  MADRID     SEVILLA
# 2                 2 2019-04-19 05:31:43  MADRID     SEVILLA
# 3                 3 2019-04-19 05:31:43  MADRID     SEVILLA
# 4                 4 2019-04-19 05:31:43  MADRID     SEVILLA
# 5                 5 2019-04-19 05:31:43  MADRID     SEVILLA
# 6                 6 2019-04-19 05:31:43  MADRID     SEVILLA
# 7                 7 2019-04-19 05:31:43  MADRID     SEVILLA
# 8                 8 2019-04-19 05:31:43  MADRID     SEVILLA
# 9                 9 2019-04-19 05:31:43  MADRID     SEVILLA
# 10               10 2019-04-19 05:31:43  MADRID     SEVILLA
# 11               11 2019-04-19 05:31:43  MADRID     SEVILLA
# 12               12 2019-04-19 05:31:43  MADRID     SEVILLA
# 13               13 2019-04-19 05:31:43  MADRID     SEVILLA
# 14               14 2019-04-19 05:31:43  MADRID     SEVILLA
# ...

# %%
renfe.dtypes
# Out:
# Unnamed: 0              int64
# insert_date    datetime64[ns]
# origin                 object
# destination            object
# start_date     datetime64[ns]
# end_date               object
# train_type             object
# price                 float64
# train_class            object
# fare                   object
# dtype: object

# %%
renfe_check_distinct_journeys = renfe.copy()

# %%
renfe_check_distinct_journeys.index = [pd.DatetimeIndex(renfe['start_date']), renfe['train_type']]

# %%
renfe_check_distinct_journeys
# Out:
#                                 Unnamed: 0         insert_date  origin  \
# start_date          train_type
# 2019-05-29 06:20:00 AV City              0 2019-04-19 05:31:43  MADRID
# 2019-05-29 07:00:00 AVE                  1 2019-04-19 05:31:43  MADRID
# 2019-05-29 07:30:00 AVE                  2 2019-04-19 05:31:43  MADRID
# 2019-05-29 08:00:00 AVE                  3 2019-04-19 05:31:43  MADRID
# 2019-05-29 08:30:00 ALVIA                4 2019-04-19 05:31:43  MADRID
# 2019-05-29 09:00:00 AVE                  5 2019-04-19 05:31:43  MADRID
# 2019-05-29 09:45:00 INTERCITY            6 2019-04-19 05:31:43  MADRID
# 2019-05-29 10:00:00 AVE                  7 2019-04-19 05:31:43  MADRID
# 2019-05-29 11:00:00 AVE                  8 2019-04-19 05:31:43  MADRID
# 2019-05-29 11:05:00 ALVIA                9 2019-04-19 05:31:43  MADRID
# 2019-05-29 12:00:00 AVE                 10 2019-04-19 05:31:43  MADRID
# 2019-05-29 13:00:00 AVE                 11 2019-04-19 05:31:43  MADRID
# ...

# %%
renfe_MAD_BCN = renfe_check_distinct_journeys[(renfe_check_distinct_journeys["origin"]=="MADRID") & (renfe_check_distinct_journeys["destination"]=="BARCELONA")]

# %%
renfe_MAD_BCN
# Out:
#                                 Unnamed: 0          insert_date  origin  \
# start_date          train_type
# 2019-04-27 06:20:00 AVE               1906  2019-04-19 06:00:47  MADRID
# 2019-04-27 07:30:00 AVE               1907  2019-04-19 06:00:47  MADRID
# 2019-04-27 08:30:00 AVE               1908  2019-04-19 06:00:47  MADRID
# 2019-04-27 09:30:00 AVE               1909  2019-04-19 06:00:47  MADRID
# 2019-04-27 10:30:00 AVE               1910  2019-04-19 06:00:47  MADRID
# 2019-04-27 11:30:00 AVE               1911  2019-04-19 06:00:47  MADRID
# 2019-04-27 12:30:00 AVE               1912  2019-04-19 06:00:47  MADRID
# 2019-04-27 13:25:00 AVE-TGV           1913  2019-04-19 06:00:47  MADRID
# 2019-04-27 15:30:00 AVE               1914  2019-04-19 06:00:47  MADRID
# 2019-04-27 16:30:00 AVE               1915  2019-04-19 06:00:47  MADRID
# 2019-04-27 17:30:00 AVE               1916  2019-04-19 06:00:47  MADRID
# 2019-04-27 18:30:00 AVE               1917  2019-04-19 06:00:47  MADRID
# ...

# %%
renfe_MAD_BCN.train_type.value_counts()
# Out:
# AVE          444315
# AVE-TGV       19148
# R. EXPRES     14370
# AVE-LD         1819
# LD-AVE          422
# Name: train_type, dtype: int64

# %%
renfe_BCN_MAD = renfe_check_distinct_journeys[(renfe_check_distinct_journeys["origin"]=="BARCELONA") & (renfe_check_distinct_journeys["destination"]=="MADRID")]

# %%
renfe_BCN_MAD
# Out:
#                                 Unnamed: 0          insert_date     origin  \
# start_date          train_type
# 2019-04-25 05:50:00 AVE               1815  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 06:05:00 AVE               1816  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 06:25:00 AVE               1817  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 06:40:00 AVE               1818  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 07:00:00 AVE               1819  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 07:05:00 AVE               1820  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 07:25:00 AVE               1821  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 07:40:00 AVE               1822  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 08:00:00 AVE               1823  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 08:25:00 AVE               1824  2019-04-19 05:47:27  BARCELONA
# 2019-04-25 09:00:00 AVE               1825  2019-04-19 05:47:27  BARCELONA
# ...

# %%
renfe_BCN_MAD_0550=renfe_BCN_MAD[(renfe_BCN_MAD["start_date"] == "2019-04-25 05:50:00")]

# %%
renfe_BCN_MAD_0550
# Out:
#                                 Unnamed: 0          insert_date     origin  \
# start_date          train_type
# 2019-04-25 05:50:00 AVE               1815  2019-04-19 05:47:27  BARCELONA
#                     AVE              13093  2019-04-19 07:47:20  BARCELONA
#                     AVE              18717  2019-04-19 08:47:28  BARCELONA
#                     AVE              24281  2019-04-19 09:47:04  BARCELONA
#                     AVE              28163  2019-04-19 10:30:32  BARCELONA
#                     AVE              35265  2019-04-19 11:47:09  BARCELONA
#                     AVE              41177  2019-04-19 12:47:08  BARCELONA
#                     AVE              42358  2019-04-19 13:11:25  BARCELONA
#                     AVE              50610  2019-04-19 14:31:06  BARCELONA
#                     AVE              52371  2019-04-19 15:00:50  BARCELONA
#                     AVE              60628  2019-04-19 16:25:29  BARCELONA
# ...

# %%
renfe_BCN_MAD_0550.train_type.value_counts()
# Out:
# AVE    206
# Name: train_type, dtype: int64

# %%
renfe_BCN_MAD_0550.insert_date.value_counts().sort_index(ascending=False)
# Out:
# 2019-04-25 03:05:27    1
# 2019-04-25 01:03:08    1
# 2019-04-24 23:20:34    1
# 2019-04-24 21:12:22    1
# 2019-04-24 19:13:35    1
# 2019-04-24 17:06:01    1
# 2019-04-24 11:12:15    1
# 2019-04-24 09:45:51    1
# 2019-04-24 08:12:31    1
# 2019-04-24 07:00:46    1
# 2019-04-24 06:16:22    1
# 2019-04-24 05:10:25    1
# 2019-04-24 04:12:58    1
# 2019-04-24 03:47:42    1
# 2019-04-24 00:44:24    1
# 2019-04-23 23:11:00    1
# 2019-04-23 22:35:48    1
# 2019-04-23 20:15:08    1
# 2019-04-23 19:43:16    1
# 2019-04-23 18:02:30    1
# 2019-04-23 17:18:49    1
# 2019-04-23 16:11:33    1
# 2019-04-23 15:04:27    1
# 2019-04-23 14:27:23    1
# 2019-04-23 13:33:14    1
# 2019-04-23 12:44:33    1
# 2019-04-23 11:19:10    1
# 2019-04-23 10:04:16    1
# 2019-04-23 09:15:34    1
# 2019-04-23 08:16:58    1
#                       ..
# 2019-04-15 17:11:04    1
# 2019-04-15 16:16:27    1
# 2019-04-15 15:00:27    1
# 2019-04-15 14:08:30    1
# 2019-04-15 13:10:37    1
# 2019-04-15 12:15:30    1
# ...

# %%
renfe["start_date"] = pd.to_datetime(renfe["start_date"])

# %%
renfe["insert_date"] = pd.to_datetime(renfe["insert_date"])

# %%
renfe_BCN_MAD_0550.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 206 entries, (2019-04-25 05:50:00, AVE) to (2019-04-25 05:50:00, AVE)
# Data columns (total 10 columns):
# Unnamed: 0     206 non-null int64
# insert_date    206 non-null object
# origin         206 non-null object
# destination    206 non-null object
# start_date     206 non-null datetime64[ns]
# end_date       206 non-null object
# train_type     206 non-null object
# price          206 non-null float64
# train_class    206 non-null object
# fare           206 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(7)
# memory usage: 80.1+ KB

# %%
renfe_BCN_MAD_0550["time_departing"] = renfe_BCN_MAD_0550.start_date.dt.time
# Out:
# /home/salva/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
renfe_BCN_MAD_0550["date_departing"] = renfe_BCN_MAD_0550.start_date.dt.date
# Out:
# /home/salva/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
renfe_BCN_MAD_0550["date_price_check"] = renfe_BCN_MAD_0550.insert_date.dt.date
# Out:
# /home/salva/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
renfe_BCN_MAD_0550.head()
# Out:
#                                 Unnamed: 0         insert_date     origin  \
# start_date          train_type
# 2019-04-25 05:50:00 AVE               1815 2019-04-19 05:47:27  BARCELONA
#                     AVE              13093 2019-04-19 07:47:20  BARCELONA
#                     AVE              18717 2019-04-19 08:47:28  BARCELONA
#                     AVE              24281 2019-04-19 09:47:04  BARCELONA
#                     AVE              28163 2019-04-19 10:30:32  BARCELONA
#
#                                destination          start_date  \
# start_date          train_type
# 2019-04-25 05:50:00 AVE             MADRID 2019-04-25 05:50:00
#                     AVE             MADRID 2019-04-25 05:50:00
#                     AVE             MADRID 2019-04-25 05:50:00
#                     AVE             MADRID 2019-04-25 05:50:00
#                     AVE             MADRID 2019-04-25 05:50:00
#
#                                            end_date train_type  price  \
# ...

# %%
renfe_BCN_MAD_0550.date_price_check.unique()
# Out:
# array([datetime.date(2019, 4, 19), datetime.date(2019, 4, 20),
#        datetime.date(2019, 4, 21), datetime.date(2019, 4, 22),
#        datetime.date(2019, 4, 23), datetime.date(2019, 4, 24),
#        datetime.date(2019, 4, 25), datetime.date(2019, 4, 14),
#        datetime.date(2019, 4, 15), datetime.date(2019, 4, 16),
#        datetime.date(2019, 4, 17), datetime.date(2019, 4, 18)],
#       dtype=object)

# %%
renfe_0550_check_window = renfe_BCN_MAD_0550[(renfe_BCN_MAD_0550["time_price_check"] > hour) & (renfe_BCN_MAD_0550["time_price_check"] < hour2)]

# %%
hour = datetime.datetime.strptime("2019-04-25 17:00:00", "%Y-%m-%d %H:%M:%S").time()

# %%
hour2 = datetime.datetime.strptime("2019-04-25 20:59:59", "%Y-%m-%d %H:%M:%S").time()

# %%
datetime.time.strftime(hour, "%Y-%m-%d %H:%M:%S")
# Out:
# '1900-01-01 17:00:00'

# %%
renfe_0550_check_window.date_price_check.nunique()
# Out:
# 11

# %%
renfe[(renfe.origin=="PONFERRADA") | (renfe.destination=="PONFERRADA")]

# %%
renfe = renfe.set_index("city")
renfe = renfe.drop("Ponferrada", axis=0)
