# %%
import os
import pandas as pd
import numpy as np
import datetime
from datetime import time

# %%
renfe = pd.read_csv("../Data/renfe.csv")

# %% [markdown]
# ##### Getting to further know the content of the data

# %%
renfe.head()
# Out:
#    Unnamed: 0          insert_date  origin destination           start_date  \
# 0           0  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 06:20:00
# 1           1  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 07:00:00
# 2           2  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 07:30:00
# 3           3  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 08:00:00
# 4           4  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 08:30:00
#
#               end_date train_type  price train_class   fare
# 0  2019-05-29 09:16:00    AV City  38.55     Turista  Promo
# 1  2019-05-29 09:32:00        AVE  53.40     Turista  Promo
# 2  2019-05-29 09:51:00        AVE  47.30     Turista  Promo
# 3  2019-05-29 10:32:00        AVE  69.40  Preferente  Promo
# 4  2019-05-29 11:14:00      ALVIA    NaN     Turista  Promo

# %%
renfe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2579771 entries, 0 to 2579770
# Data columns (total 10 columns):
# Unnamed: 0     int64
# insert_date    object
# origin         object
# destination    object
# start_date     object
# end_date       object
# train_type     object
# price          float64
# train_class    object
# fare           object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 196.8+ MB

# %%
renfe.origin.value_counts()
# Out:
# MADRID        1359423
# BARCELONA      405621
# SEVILLA        398445
# VALENCIA       323086
# PONFERRADA      93196
# Name: origin, dtype: int64

# %%
renfe.destination.value_counts()
# Out:
# MADRID        1220348
# BARCELONA      480074
# SEVILLA        413155
# VALENCIA       399679
# PONFERRADA      66515
# Name: destination, dtype: int64

# %%
renfe.train_type.value_counts()
# Out:
# AVE          1789258
# ALVIA         182267
# REGIONAL      145898
# INTERCITY      99840
# AV City        72791
# MD-LD          51585
# LD             41209
# AVE-TGV        34755
# AVE-MD         34182
# R. EXPRES      31918
# AVE-LD         31472
# LD-MD          27305
# TRENHOTEL      19348
# MD-AVE          7592
# MD              5543
# LD-AVE          4808
# Name: train_type, dtype: int64

# %%
renfe[renfe["train_type"]=="TRENHOTEL"].tail(30)
# Out:
#          Unnamed: 0          insert_date      origin destination  \
# 2574404     2574404  2019-04-19 04:34:34  PONFERRADA      MADRID
# 2574432     2574432  2019-04-19 04:35:05  PONFERRADA      MADRID
# 2574436     2574436  2019-04-19 04:35:10  PONFERRADA      MADRID
# 2574445     2574445  2019-04-19 04:35:21  PONFERRADA      MADRID
# 2577089     2577089  2019-04-19 05:05:21      MADRID  PONFERRADA
# 2577097     2577097  2019-04-19 05:05:34      MADRID  PONFERRADA
# 2577102     2577102  2019-04-19 05:05:42      MADRID  PONFERRADA
# 2577106     2577106  2019-04-19 05:06:43      MADRID  PONFERRADA
# 2577128     2577128  2019-04-19 05:07:51      MADRID  PONFERRADA
# 2577151     2577151  2019-04-19 05:08:25      MADRID  PONFERRADA
# 2577155     2577155  2019-04-19 05:08:27      MADRID  PONFERRADA
# 2577160     2577160  2019-04-19 05:08:39      MADRID  PONFERRADA
# 2577165     2577165  2019-04-19 05:08:41      MADRID  PONFERRADA
# ...

# %%
renfe.train_class.value_counts()
# Out:
# Turista               1950303
# Preferente             256082
# Turista Plus           192908
# Turista con enlace     169549
# Cama Turista             1051
# Cama G. Clase             214
# Name: train_class, dtype: int64

# %%
renfe.fare.value_counts()
# Out:
# Promo                  1733423
# Flexible                582743
# Adulto ida              179844
# Promo +                  73778
# Individual-Flexible        214
# Mesa                        99
# Grupos Ida                   6
# Name: fare, dtype: int64

# %% [markdown]
# ##### Dropping unnecessary column

# %%
renfe.drop("Unnamed: 0", axis=1, inplace=True)

# %% [markdown]
# ##### Renaming columns

# %%
renfe = renfe.rename(columns={"insert_date":"price_check"})

# %%
renfe = renfe.rename(columns={"price_check":"price_check_datetime"})

# %%
renfe = renfe.rename(columns={"train_class":"ticket_class"})

# %%
renfe.head()

# %%
test = renfe.pivot_table(index=["city_origin_code","city_destination_code","departing_date", "departing_time"], columns=["date_lag"], values=["price"], aggfunc="mean")

# %%
test

# %%
renfe.price_check_date.value_counts().sort_index(ascending=True)

# %%
renfe.departing_date.value_counts().sort_index(ascending=True)

# %% [markdown]
# ##### Understanding we have price check for trains departing beyond 05-June for all the range possible (27 days

# %%
renfe[(renfe["departing_date"]>date_limit)&(renfe["date_lag"]>"27 days")]

# %%
date_limit = datetime.datetime.strptime("2019-06-05 00:00:00", "%Y-%m-%d %H:%M:%S").date()

# %%
date_limit_2 = datetime.datetime.strptime("2019-04-19 00:00:00", "%Y-%m-%d %H:%M:%S").date()

# %%
renfe.date_lag.value_counts().sort_index(ascending=True)
